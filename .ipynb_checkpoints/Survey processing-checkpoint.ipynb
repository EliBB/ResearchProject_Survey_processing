# %%
# Linear algebra
import numpy as np

# Data processing and CSV file
import pandas as pd

# Data visualization
import matplotlib.pyplot as plt

# Read data from CSV file
data = 'For the love of knitting.csv'
df = pd.read_csv(data)

# %%
df.head()
# Out:
#                  Tidsstempel For how long have you been knitting?  \
# 0  2022/10/07 2:35:29 PM CET                   More than 20 years
# 1  2022/10/07 2:41:54 PM CET                   More than 20 years
# 2  2022/10/07 2:49:22 PM CET                        11 - 20 years
# 3  2022/10/07 2:51:05 PM CET                   More than 20 years
# 4  2022/10/07 2:56:25 PM CET                   More than 20 years
#
#   How often do you knit?  \
# 0                  Daily
# 1                  Daily
# 2                  Daily
# 3                 Weekly
# 4                  Daily
#
#   How many consecutive hours do you knit per session? (Chose the answer that fits the best on average)  \
# 0                                        1 - 2 hours
# 1                                        1 - 2 hours
# 2                                        1 - 2 hours
# 3                                        1 - 2 hours
# 4                                        3 - 4 hours
#
# ...

# %%
col_names = ['Date', 'Experience', 'Frequency', 'Hours', 'Country', 'Reason', 'Introduction', 'Place', 'Inspiration', 'FavoriteKnittingProject', 'SizeProject','ChooseYarn', 'BuyYarn', 'Notes', 'OverallTools','ImportantTools', 'Level', 'Motivation', 'GetHelp', 'PatternType', 'AppTools', 'SharingData', 'WhyShare?', 'AnythingElse', 'test']

df.columns = col_names

df.columns
# Out:
# Index(['Date', 'Experience', 'Frequency', 'Hours', 'Country', 'Reason',
#        'Introduction', 'Place', 'Inspiration', 'FavoriteKnittingProject',
#        'SizeProject', 'ChooseYarn', 'BuyYarn', 'Notes', 'OverallTools',
#        'ImportantTools', 'Level', 'Motivation', 'GetHelp', 'PatternType',
#        'AppTools', 'SharingData', 'WhyShare?', 'AnythingElse', 'test'],
#       dtype='object')

# %%
df.head()
# Out:
#                         Date          Experience Frequency        Hours  \
# 0  2022/10/07 2:35:29 PM CET  More than 20 years     Daily  1 - 2 hours
# 1  2022/10/07 2:41:54 PM CET  More than 20 years     Daily  1 - 2 hours
# 2  2022/10/07 2:49:22 PM CET       11 - 20 years     Daily  1 - 2 hours
# 3  2022/10/07 2:51:05 PM CET  More than 20 years    Weekly  1 - 2 hours
# 4  2022/10/07 2:56:25 PM CET  More than 20 years     Daily  3 - 4 hours
#
#                        Country  \
# 0                      Germany
# 1                          USA
# 2                       Canada
# 3                          USA
# 4  What, Canada doesn't exist?
#
#                                               Reason  \
# 0  Get relaxed and relief stress;To let the hours...
# 1  Being creative by trying new stitch types, kni...
# 2  Get relaxed and relief stress;Being creative b...
# 3  Get relaxed and relief stress;Being creative b...
# 4  Get relaxed and relief stress;Being creative b...
#
# ...

# %%
ExperienceCount = df.Experience.value_counts()

x = ExperienceCount

labels = 'More than 20 years', '11-20 years', '1-5 years', '6-10 years',

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=15)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Knitting experience')
plt.show()

# %%
FrequencyCount = df.Frequency.value_counts()

x = FrequencyCount

labels = 'Daily', 'Weekly', 'Monthly',

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=15)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Knitting frequency')
plt.show()

# %%
HoursCount = df.Hours.value_counts()

x = HoursCount

labels = '1-2 hours', '3-4 hours', 'Less than an hour', 'More than 5 hours'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=15)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Knitting duration')
plt.show()

# %%
Country = df['Country']

listOfContinents = []

def sortCountries():
    
    listOfContinents = []

    for knitter in Country:
        
        if knitter == 'USA' or knitter == 'Canada':
            Continent = 'North America'
            #listOfContinents.append(Continent)
            
        elif knitter == 'Japan':
            Continent = 'Asia'
            #listOfContinents.append(Continent)
            
        elif knitter == 'New Zealand':
            Continent = 'Australia' 
            #listOfContinents.append(Continent)
            
        else:
            Continent = 'Europe'
            #listOfContinents.append(Continent)
            
        listOfContinents.append(Continent)
    
    
    #print(listOfContinents)
    print(pd.value_counts(np.array(listOfContinents)))
    #return listOfContinents

sortCountries()



#North America    115
#Europe            44
#Asia               1
#Australia          1


data = [115, 44, 1, 1]



labels = 'North Amercia', 'Europe', 'Asia', 'Australia'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(data, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,

       wedgeprops = wedgeprops,

       startangle=15)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Geographical location')
plt.show()
# Out:
# North America    115
# Europe            44
# Asia               1
# Australia          1
# dtype: int64

# %%
PatternCount = df.PatternType.value_counts()

x = PatternCount

labels = 'Physical', 'Digital'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=15)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Preferred knitting pattern')
plt.show()

# %%
DataCount = df.SharingData.value_counts()

x = DataCount

labels = 'It could be nice to share the data on multiple devices', ' I would like to keep my data on one device'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=0)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Sharing data between devices')
plt.show()

# %%
SizeProject = df.SizeProject.value_counts()

x = SizeProject

labels = 'Large projects', 'Small projects', 'Medium projects'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Size of knitting project')
plt.show()

# %%
Level = df.Level.value_counts()

x = Level

labels = 'The difficult level does not hold me back', 'I make sure I can do all techniques'

colors = ['#FFF5F5', '#E3CDCC', '#C4A9A5', '#795C58']

wedgeprops = { 'edgecolor' : '#666666'}


fig, ax = plt.subplots()
ax.pie(x, 
       autopct='%1.1f%%',
       labels=labels, 
       colors=colors,
       wedgeprops = wedgeprops,
       startangle=90)
ax.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.title('Preparation of knitting project')
plt.show()
